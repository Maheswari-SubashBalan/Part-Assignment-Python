# %%
# 1.String Concatenation

string1 = "Hello"
string2 = input("Enter your name:")

Concatenate_string = string1+" "+string2
print(Concatenate_string)

string3 = "Welcome to Python Programming"
result_string = Concatenate_string+", "+string3
print(result_string)


# 2.String Slicing and Indexing
##a.Print the first character of the string.
print("F_character:", result_string[0])
##b.Print the last character of the string.
print("L_character:", result_string[-1])
##c.Print the first 5 characters of the string.
print("First 5 characters:",result_string[:5])
##d.Print the last 11 characters of the string.
print("Last 11 characters:",result_string[-11:])
##e.Print the string in reverse.
print("Reverse:",result_string[::-1])
##f.Use slicing and print the word “Python” from the existing string.
print("Slicing_word:",result_string[23:30])

# 3.String Methods

strM = "Python beginner tutorial,"
##a.Convert the sentence to uppercase
print(strM.upper())

##b.Convert the sentence to lowercase.
print(strM.lower())

##c.Use Capitalize and return the sentence to the original input form.
print(strM.capitalize())

##d.Count the total number of occurrences of character ‘t’ in the string.
count_t = strM.count('t')
print(count_t)

##e.Replace all occurrences of “Python” with “Data Analytics” in the input string strM = “Python beginner tutorial.”
replace_value = strM.replace("Python","Data Analystics")
print(replace_value)
# Out:
# Enter your name:Mekha
# Hello Mekha
# Hello Mekha, Welcome to Python Programming
# F_character: H
# L_character: g
# First 5 characters: Hello
# Last 11 characters: Programming
# Reverse: gnimmargorP nohtyP ot emocleW ,ahkeM olleH
# Slicing_word:  Python
# PYTHON BEGINNER TUTORIAL,
# python beginner tutorial,
# Python beginner tutorial,
# 3
# Data Analystics beginner tutorial,

# %%
#Tuples (Creation, Modification and Access):

tuple1 = (10,20,30)
tuple2 = (40,50,60)

##a.Concatenate the two tuples and store it in “t_combine”
t_combine = tuple1+tuple2
print(t_combine)

##b.Repeat the elements of “t_combine” 3 times
repeat_value = t_combine * 3
print(repeat_value)

##c.Access the 3rd element from “t_combine”
print("Third element:",t_combine[2])

##d.Access the first three elements from “t_combine”
print(t_combine[:3])

##e.Access the last three elements from “t_combine”
print(t_combine[-3:])
# Out:
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# Third element: 30
# (10, 20, 30)
# (40, 50, 60)
